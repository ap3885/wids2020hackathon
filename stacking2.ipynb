# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
#from sklearn.cross_validation import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

# %%
train = pd.read_csv('./train-new.csv')
test = pd.read_csv('./test-new.csv')

# %%
def dummies(train, test):
    columns = ['ethnicity', 'gender','icu_stay_type','hospital_admit_source', 'icu_admit_source', 'icu_type', 'apache_3j_bodysystem', 'apache_2_bodysystem', 'cancer', 'liver_disease', 'other']
    for column in columns:
        train[column] = train[column].apply(lambda x: str(x))
        test[column] = test[column].apply(lambda x: str(x))
        good_cols = [column+'_'+i for i in train[column].unique() if i in test[column].unique()]
        train = pd.concat((train, pd.get_dummies(train[column], prefix = column)[good_cols]), axis = 1)
        test = pd.concat((test, pd.get_dummies(test[column], prefix = column)[good_cols]), axis = 1)
        del train[column]
        del test[column]
    return train, test

# %%
train, test = dummies(train, test)

# %%
y_train = train['hospital_death'].ravel()
train1 = train.drop(['hospital_death'], axis=1)
test1 = test.drop(['hospital_death'], axis=1)
x_train = train1.values # Creates an array of the train data
x_test = test1.values # Creats an array of the test data
ntrain = x_train.shape[0]
ntest = x_test.shape[0]

# %%
NFOLDS = 5
SEED = 0
NROWS = None
kf = KFold(n_splits = NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
        
class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train[train_index]
        y_tr = y_train[train_index]
        x_te = x_train[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 250,
    'max_features': 0.75,
    'max_depth': 6,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 250,
    'max_features': 0.75,
    'max_depth': 6,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.3,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.2,
    'objective': 'binary:logistic',
    'max_depth': 6,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.2,
    'depth': 6 ,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'MVS',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':250,
    'learning_rate':0.2,
    'num_leaves':1400,
    'colsample_bytree':0.5,
    'subsample':0.9,
    'max_depth':6,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':1    
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

# %%
xg_oof_train, xg_oof_test = get_oof(xg)
print("testing2")
et_oof_train, et_oof_test = get_oof(et)
print("testing3")
rf_oof_train, rf_oof_test = get_oof(rf)
print("testing4")
cb_oof_train, cb_oof_test = get_oof(cb)
print("Training completed")
# Out:
# testing2
# testing3
# testing4
# 0:	total: 174ms	remaining: 34.6s
# 1:	total: 202ms	remaining: 20s
# 2:	total: 230ms	remaining: 15.1s
# 3:	total: 258ms	remaining: 12.6s
# 4:	total: 285ms	remaining: 11.1s
# 5:	total: 312ms	remaining: 10.1s
# 6:	total: 340ms	remaining: 9.36s
# 7:	total: 367ms	remaining: 8.82s
# 8:	total: 411ms	remaining: 8.73s
# 9:	total: 442ms	remaining: 8.4s
# 10:	total: 473ms	remaining: 8.13s
# 11:	total: 504ms	remaining: 7.89s
# 12:	total: 534ms	remaining: 7.68s
# 13:	total: 581ms	remaining: 7.72s
# 14:	total: 613ms	remaining: 7.56s
# 15:	total: 647ms	remaining: 7.43s
# 16:	total: 679ms	remaining: 7.3s
# 17:	total: 713ms	remaining: 7.21s
# 18:	total: 747ms	remaining: 7.12s
# 19:	total: 791ms	remaining: 7.12s
# 20:	total: 826ms	remaining: 7.04s
# 21:	total: 859ms	remaining: 6.95s
# 22:	total: 892ms	remaining: 6.86s
# 23:	total: 926ms	remaining: 6.79s
# 24:	total: 962ms	remaining: 6.73s
# 25:	total: 1.01s	remaining: 6.74s
# 26:	total: 1.05s	remaining: 6.73s
# 27:	total: 1.09s	remaining: 6.7s
# 28:	total: 1.13s	remaining: 6.64s
# 29:	total: 1.16s	remaining: 6.59s
# 30:	total: 1.21s	remaining: 6.58s
# 31:	total: 1.24s	remaining: 6.52s
# 32:	total: 1.28s	remaining: 6.46s
# 33:	total: 1.31s	remaining: 6.39s
# 34:	total: 1.34s	remaining: 6.33s
# 35:	total: 1.39s	remaining: 6.31s
# 36:	total: 1.43s	remaining: 6.28s
# 37:	total: 1.46s	remaining: 6.24s
# 38:	total: 1.5s	remaining: 6.19s
# 39:	total: 1.53s	remaining: 6.13s
# 40:	total: 1.58s	remaining: 6.11s
# 41:	total: 1.61s	remaining: 6.08s
# 42:	total: 1.66s	remaining: 6.04s
# 43:	total: 1.69s	remaining: 6s
# 44:	total: 1.73s	remaining: 5.95s
# 45:	total: 1.76s	remaining: 5.89s
# 46:	total: 1.8s	remaining: 5.85s
# 47:	total: 1.83s	remaining: 5.8s
# 48:	total: 1.88s	remaining: 5.78s
# 49:	total: 1.91s	remaining: 5.74s
# 50:	total: 1.95s	remaining: 5.7s
# 51:	total: 1.99s	remaining: 5.65s
# 52:	total: 2.02s	remaining: 5.61s
# 53:	total: 2.06s	remaining: 5.57s
# 54:	total: 2.1s	remaining: 5.54s
# 55:	total: 2.14s	remaining: 5.5s
# 56:	total: 2.18s	remaining: 5.46s
# 57:	total: 2.21s	remaining: 5.42s
# 58:	total: 2.25s	remaining: 5.38s
# 59:	total: 2.3s	remaining: 5.36s
# 60:	total: 2.34s	remaining: 5.33s
# 61:	total: 2.37s	remaining: 5.28s
# 62:	total: 2.4s	remaining: 5.23s
# 63:	total: 2.44s	remaining: 5.18s
# 64:	total: 2.48s	remaining: 5.16s
# 65:	total: 2.52s	remaining: 5.12s
# 66:	total: 2.56s	remaining: 5.08s
# 67:	total: 2.59s	remaining: 5.03s
# 68:	total: 2.63s	remaining: 4.99s
# 69:	total: 2.67s	remaining: 4.95s
# 70:	total: 2.7s	remaining: 4.91s
# 71:	total: 2.74s	remaining: 4.87s
# 72:	total: 2.77s	remaining: 4.82s
# 73:	total: 2.81s	remaining: 4.78s
# 74:	total: 2.85s	remaining: 4.75s
# 75:	total: 2.88s	remaining: 4.71s
# 76:	total: 2.92s	remaining: 4.66s
# 77:	total: 2.95s	remaining: 4.62s
# 78:	total: 2.98s	remaining: 4.57s
# 79:	total: 3.02s	remaining: 4.54s
# 80:	total: 3.07s	remaining: 4.5s
# 81:	total: 3.1s	remaining: 4.46s
# 82:	total: 3.13s	remaining: 4.42s
# 83:	total: 3.17s	remaining: 4.37s
# 84:	total: 3.2s	remaining: 4.33s
# 85:	total: 3.25s	remaining: 4.3s
# 86:	total: 3.29s	remaining: 4.28s
# 87:	total: 3.33s	remaining: 4.25s
# 88:	total: 3.37s	remaining: 4.21s
# 89:	total: 3.41s	remaining: 4.17s
# 90:	total: 3.44s	remaining: 4.12s
# 91:	total: 3.49s	remaining: 4.09s
# 92:	total: 3.54s	remaining: 4.07s
# 93:	total: 3.58s	remaining: 4.04s
# 94:	total: 3.61s	remaining: 3.99s
# 95:	total: 3.65s	remaining: 3.96s
# 96:	total: 3.7s	remaining: 3.93s
# 97:	total: 3.73s	remaining: 3.89s
# 98:	total: 3.77s	remaining: 3.84s
# 99:	total: 3.8s	remaining: 3.8s
# 100:	total: 3.84s	remaining: 3.76s
# 101:	total: 3.87s	remaining: 3.72s
# 102:	total: 3.92s	remaining: 3.69s
# 103:	total: 3.95s	remaining: 3.65s
# 104:	total: 3.98s	remaining: 3.6s
# 105:	total: 4.02s	remaining: 3.56s
# 106:	total: 4.06s	remaining: 3.53s
# 107:	total: 4.11s	remaining: 3.5s
# 108:	total: 4.16s	remaining: 3.47s
# 109:	total: 4.2s	remaining: 3.43s
# 110:	total: 4.23s	remaining: 3.39s
# 111:	total: 4.26s	remaining: 3.35s
# 112:	total: 4.31s	remaining: 3.32s
# 113:	total: 4.35s	remaining: 3.28s
# 114:	total: 4.39s	remaining: 3.25s
# 115:	total: 4.43s	remaining: 3.21s
# 116:	total: 4.47s	remaining: 3.17s
# 117:	total: 4.51s	remaining: 3.13s
# 118:	total: 4.55s	remaining: 3.09s
# 119:	total: 4.58s	remaining: 3.05s
# 120:	total: 4.61s	remaining: 3.01s
# 121:	total: 4.65s	remaining: 2.97s
# 122:	total: 4.69s	remaining: 2.94s
# 123:	total: 4.73s	remaining: 2.9s
# 124:	total: 4.76s	remaining: 2.86s
# 125:	total: 4.79s	remaining: 2.81s
# 126:	total: 4.83s	remaining: 2.77s
# 127:	total: 4.87s	remaining: 2.74s
# 128:	total: 4.91s	remaining: 2.7s
# 129:	total: 4.94s	remaining: 2.66s
# 130:	total: 4.97s	remaining: 2.62s
# 131:	total: 5s	remaining: 2.58s
# 132:	total: 5.04s	remaining: 2.54s
# 133:	total: 5.08s	remaining: 2.5s
# 134:	total: 5.12s	remaining: 2.47s
# 135:	total: 5.16s	remaining: 2.43s
# 136:	total: 5.19s	remaining: 2.39s
# 137:	total: 5.23s	remaining: 2.35s
# 138:	total: 5.26s	remaining: 2.31s
# 139:	total: 5.3s	remaining: 2.27s
# 140:	total: 5.34s	remaining: 2.23s
# 141:	total: 5.38s	remaining: 2.19s
# 142:	total: 5.41s	remaining: 2.15s
# 143:	total: 5.44s	remaining: 2.12s
# 144:	total: 5.51s	remaining: 2.09s
# 145:	total: 5.56s	remaining: 2.06s
# 146:	total: 5.59s	remaining: 2.02s
# 147:	total: 5.63s	remaining: 1.98s
# 148:	total: 5.67s	remaining: 1.94s
# 149:	total: 5.71s	remaining: 1.9s
# 150:	total: 5.74s	remaining: 1.86s
# 151:	total: 5.78s	remaining: 1.82s
# 152:	total: 5.81s	remaining: 1.79s
# 153:	total: 5.85s	remaining: 1.75s
# 154:	total: 5.9s	remaining: 1.71s
# 155:	total: 5.93s	remaining: 1.67s
# 156:	total: 5.97s	remaining: 1.63s
# 157:	total: 6s	remaining: 1.59s
# 158:	total: 6.03s	remaining: 1.56s
# 159:	total: 6.08s	remaining: 1.52s
# 160:	total: 6.11s	remaining: 1.48s
# 161:	total: 6.14s	remaining: 1.44s
# 162:	total: 6.18s	remaining: 1.4s
# 163:	total: 6.21s	remaining: 1.36s
# 164:	total: 6.25s	remaining: 1.32s
# 165:	total: 6.29s	remaining: 1.29s
# 166:	total: 6.33s	remaining: 1.25s
# 167:	total: 6.36s	remaining: 1.21s
# 168:	total: 6.4s	remaining: 1.17s
# 169:	total: 6.43s	remaining: 1.14s
# 170:	total: 6.47s	remaining: 1.1s
# 171:	total: 6.51s	remaining: 1.06s
# 172:	total: 6.54s	remaining: 1.02s
# 173:	total: 6.58s	remaining: 984ms
# 174:	total: 6.62s	remaining: 946ms
# 175:	total: 6.66s	remaining: 908ms
# 176:	total: 6.7s	remaining: 870ms
# 177:	total: 6.74s	remaining: 833ms
# 178:	total: 6.77s	remaining: 794ms
# 179:	total: 6.8s	remaining: 756ms
# 180:	total: 6.84s	remaining: 718ms
# 181:	total: 6.88s	remaining: 681ms
# 182:	total: 6.92s	remaining: 643ms
# 183:	total: 6.95s	remaining: 605ms
# 184:	total: 6.99s	remaining: 567ms
# 185:	total: 7.03s	remaining: 529ms
# 186:	total: 7.07s	remaining: 491ms
# 187:	total: 7.11s	remaining: 454ms
# 188:	total: 7.14s	remaining: 416ms
# 189:	total: 7.18s	remaining: 378ms
# 190:	total: 7.22s	remaining: 340ms
# 191:	total: 7.25s	remaining: 302ms
# 192:	total: 7.29s	remaining: 265ms
# 193:	total: 7.33s	remaining: 227ms
# 194:	total: 7.36s	remaining: 189ms
# 195:	total: 7.39s	remaining: 151ms
# 196:	total: 7.44s	remaining: 113ms
# 197:	total: 7.49s	remaining: 75.6ms
# 198:	total: 7.52s	remaining: 37.8ms
# 199:	total: 7.55s	remaining: 0us
# 0:	total: 29.1ms	remaining: 5.8s
# 1:	total: 56.4ms	remaining: 5.58s
# 2:	total: 83.6ms	remaining: 5.49s
# 3:	total: 111ms	remaining: 5.44s
# 4:	total: 138ms	remaining: 5.38s
# 5:	total: 166ms	remaining: 5.38s
# 6:	total: 196ms	remaining: 5.39s
# 7:	total: 225ms	remaining: 5.39s
# 8:	total: 263ms	remaining: 5.57s
# 9:	total: 293ms	remaining: 5.56s
# 10:	total: 322ms	remaining: 5.54s
# 11:	total: 353ms	remaining: 5.52s
# 12:	total: 384ms	remaining: 5.52s
# 13:	total: 418ms	remaining: 5.56s
# 14:	total: 457ms	remaining: 5.64s
# 15:	total: 489ms	remaining: 5.62s
# 16:	total: 522ms	remaining: 5.62s
# 17:	total: 554ms	remaining: 5.6s
# 18:	total: 585ms	remaining: 5.57s
# 19:	total: 619ms	remaining: 5.57s
# 20:	total: 664ms	remaining: 5.66s
# 21:	total: 705ms	remaining: 5.7s
# 22:	total: 747ms	remaining: 5.75s
# 23:	total: 783ms	remaining: 5.75s
# 24:	total: 818ms	remaining: 5.73s
# 25:	total: 858ms	remaining: 5.75s
# 26:	total: 894ms	remaining: 5.73s
# 27:	total: 930ms	remaining: 5.71s
# 28:	total: 965ms	remaining: 5.69s
# 29:	total: 1s	remaining: 5.67s
# 30:	total: 1.05s	remaining: 5.72s
# 31:	total: 1.09s	remaining: 5.72s
# 32:	total: 1.13s	remaining: 5.7s
# 33:	total: 1.16s	remaining: 5.66s
# 34:	total: 1.19s	remaining: 5.63s
# 35:	total: 1.23s	remaining: 5.61s
# 36:	total: 1.27s	remaining: 5.61s
# 37:	total: 1.31s	remaining: 5.59s
# 38:	total: 1.35s	remaining: 5.56s
# 39:	total: 1.38s	remaining: 5.52s
# 40:	total: 1.43s	remaining: 5.54s
# 41:	total: 1.48s	remaining: 5.55s
# 42:	total: 1.51s	remaining: 5.51s
# 43:	total: 1.54s	remaining: 5.47s
# 44:	total: 1.58s	remaining: 5.43s
# 45:	total: 1.61s	remaining: 5.39s
# 46:	total: 1.65s	remaining: 5.38s
# 47:	total: 1.69s	remaining: 5.35s
# 48:	total: 1.72s	remaining: 5.31s
# 49:	total: 1.76s	remaining: 5.27s
# 50:	total: 1.79s	remaining: 5.24s
# 51:	total: 1.84s	remaining: 5.22s
# 52:	total: 1.87s	remaining: 5.2s
# 53:	total: 1.91s	remaining: 5.16s
# 54:	total: 1.94s	remaining: 5.12s
# 55:	total: 1.98s	remaining: 5.08s
# 56:	total: 2.02s	remaining: 5.07s
# 57:	total: 2.06s	remaining: 5.04s
# 58:	total: 2.09s	remaining: 5s
# 59:	total: 2.13s	remaining: 4.96s
# 60:	total: 2.16s	remaining: 4.93s
# 61:	total: 2.2s	remaining: 4.91s
# 62:	total: 2.24s	remaining: 4.88s
# 63:	total: 2.28s	remaining: 4.84s
# 64:	total: 2.31s	remaining: 4.8s
# 65:	total: 2.35s	remaining: 4.77s
# 66:	total: 2.38s	remaining: 4.73s
# 67:	total: 2.42s	remaining: 4.71s
# 68:	total: 2.46s	remaining: 4.67s
# 69:	total: 2.49s	remaining: 4.63s
# 70:	total: 2.53s	remaining: 4.59s
# 71:	total: 2.56s	remaining: 4.56s
# 72:	total: 2.6s	remaining: 4.53s
# 73:	total: 2.64s	remaining: 4.5s
# 74:	total: 2.67s	remaining: 4.46s
# 75:	total: 2.71s	remaining: 4.42s
# 76:	total: 2.74s	remaining: 4.38s
# 77:	total: 2.78s	remaining: 4.35s
# 78:	total: 2.82s	remaining: 4.32s
# 79:	total: 2.86s	remaining: 4.29s
# 80:	total: 2.9s	remaining: 4.25s
# 81:	total: 2.93s	remaining: 4.22s
# 82:	total: 2.97s	remaining: 4.18s
# 83:	total: 3.01s	remaining: 4.16s
# 84:	total: 3.05s	remaining: 4.12s
# 85:	total: 3.08s	remaining: 4.09s
# 86:	total: 3.12s	remaining: 4.05s
# 87:	total: 3.15s	remaining: 4.01s
# 88:	total: 3.18s	remaining: 3.97s
# 89:	total: 3.21s	remaining: 3.93s
# 90:	total: 3.25s	remaining: 3.9s
# 91:	total: 3.29s	remaining: 3.86s
# 92:	total: 3.32s	remaining: 3.82s
# 93:	total: 3.36s	remaining: 3.79s
# 94:	total: 3.4s	remaining: 3.76s
# 95:	total: 3.45s	remaining: 3.73s
# 96:	total: 3.48s	remaining: 3.7s
# 97:	total: 3.52s	remaining: 3.66s
# 98:	total: 3.55s	remaining: 3.62s
# 99:	total: 3.58s	remaining: 3.58s
# 100:	total: 3.62s	remaining: 3.55s
# 101:	total: 3.66s	remaining: 3.51s
# 102:	total: 3.69s	remaining: 3.48s
# 103:	total: 3.72s	remaining: 3.44s
# 104:	total: 3.76s	remaining: 3.4s
# 105:	total: 3.8s	remaining: 3.37s
# 106:	total: 3.83s	remaining: 3.33s
# 107:	total: 3.87s	remaining: 3.3s
# 108:	total: 3.9s	remaining: 3.26s
# 109:	total: 3.94s	remaining: 3.22s
# 110:	total: 3.99s	remaining: 3.2s
# 111:	total: 4.03s	remaining: 3.17s
# 112:	total: 4.07s	remaining: 3.13s
# 113:	total: 4.11s	remaining: 3.1s
# 114:	total: 4.14s	remaining: 3.06s
# 115:	total: 4.18s	remaining: 3.02s
# 116:	total: 4.21s	remaining: 2.99s
# 117:	total: 4.24s	remaining: 2.95s
# 118:	total: 4.28s	remaining: 2.91s
# 119:	total: 4.31s	remaining: 2.88s
# 120:	total: 4.36s	remaining: 2.85s
# 121:	total: 4.39s	remaining: 2.81s
# 122:	total: 4.43s	remaining: 2.77s
# 123:	total: 4.46s	remaining: 2.74s
# 124:	total: 4.5s	remaining: 2.7s
# 125:	total: 4.54s	remaining: 2.67s
# 126:	total: 4.58s	remaining: 2.63s
# 127:	total: 4.61s	remaining: 2.6s
# 128:	total: 4.65s	remaining: 2.56s
# 129:	total: 4.68s	remaining: 2.52s
# 130:	total: 4.72s	remaining: 2.49s
# 131:	total: 4.76s	remaining: 2.45s
# 132:	total: 4.79s	remaining: 2.41s
# 133:	total: 4.83s	remaining: 2.38s
# 134:	total: 4.86s	remaining: 2.34s
# 135:	total: 4.9s	remaining: 2.3s
# 136:	total: 4.94s	remaining: 2.27s
# 137:	total: 4.97s	remaining: 2.23s
# 138:	total: 5s	remaining: 2.2s
# 139:	total: 5.04s	remaining: 2.16s
# 140:	total: 5.07s	remaining: 2.12s
# 141:	total: 5.11s	remaining: 2.09s
# 142:	total: 5.15s	remaining: 2.05s
# 143:	total: 5.19s	remaining: 2.02s
# 144:	total: 5.23s	remaining: 1.98s
# 145:	total: 5.26s	remaining: 1.95s
# 146:	total: 5.3s	remaining: 1.91s
# 147:	total: 5.34s	remaining: 1.88s
# 148:	total: 5.39s	remaining: 1.84s
# 149:	total: 5.42s	remaining: 1.81s
# 150:	total: 5.46s	remaining: 1.77s
# 151:	total: 5.49s	remaining: 1.73s
# 152:	total: 5.53s	remaining: 1.7s
# 153:	total: 5.57s	remaining: 1.66s
# 154:	total: 5.6s	remaining: 1.63s
# 155:	total: 5.64s	remaining: 1.59s
# 156:	total: 5.67s	remaining: 1.55s
# 157:	total: 5.72s	remaining: 1.52s
# 158:	total: 5.75s	remaining: 1.48s
# 159:	total: 5.79s	remaining: 1.45s
# 160:	total: 5.82s	remaining: 1.41s
# 161:	total: 5.85s	remaining: 1.37s
# 162:	total: 5.89s	remaining: 1.34s
# 163:	total: 5.93s	remaining: 1.3s
# 164:	total: 5.96s	remaining: 1.26s
# 165:	total: 6s	remaining: 1.23s
# 166:	total: 6.03s	remaining: 1.19s
# 167:	total: 6.06s	remaining: 1.16s
# 168:	total: 6.1s	remaining: 1.12s
# 169:	total: 6.14s	remaining: 1.08s
# 170:	total: 6.17s	remaining: 1.05s
# 171:	total: 6.21s	remaining: 1.01s
# 172:	total: 6.24s	remaining: 974ms
# 173:	total: 6.28s	remaining: 938ms
# 174:	total: 6.33s	remaining: 904ms
# 175:	total: 6.37s	remaining: 868ms
# 176:	total: 6.41s	remaining: 833ms
# 177:	total: 6.44s	remaining: 796ms
# 178:	total: 6.48s	remaining: 760ms
# 179:	total: 6.51s	remaining: 723ms
# 180:	total: 6.55s	remaining: 688ms
# 181:	total: 6.59s	remaining: 652ms
# 182:	total: 6.62s	remaining: 615ms
# 183:	total: 6.66s	remaining: 579ms
# 184:	total: 6.69s	remaining: 542ms
# 185:	total: 6.72s	remaining: 506ms
# 186:	total: 6.76s	remaining: 470ms
# 187:	total: 6.8s	remaining: 434ms
# 188:	total: 6.83s	remaining: 398ms
# 189:	total: 6.87s	remaining: 361ms
# 190:	total: 6.9s	remaining: 325ms
# 191:	total: 6.93s	remaining: 289ms
# 192:	total: 6.97s	remaining: 253ms
# 193:	total: 7.01s	remaining: 217ms
# 194:	total: 7.04s	remaining: 181ms
# 195:	total: 7.08s	remaining: 144ms
# 196:	total: 7.11s	remaining: 108ms
# 197:	total: 7.15s	remaining: 72.2ms
# 198:	total: 7.19s	remaining: 36.1ms
# 199:	total: 7.22s	remaining: 0us
# 0:	total: 65ms	remaining: 12.9s
# 1:	total: 93.3ms	remaining: 9.23s
# 2:	total: 122ms	remaining: 8.03s
# 3:	total: 150ms	remaining: 7.37s
# 4:	total: 178ms	remaining: 6.92s
# 5:	total: 206ms	remaining: 6.67s
# 6:	total: 234ms	remaining: 6.45s
# 7:	total: 262ms	remaining: 6.29s
# 8:	total: 300ms	remaining: 6.38s
# 9:	total: 331ms	remaining: 6.29s
# 10:	total: 364ms	remaining: 6.25s
# 11:	total: 397ms	remaining: 6.21s
# 12:	total: 427ms	remaining: 6.15s
# 13:	total: 460ms	remaining: 6.11s
# 14:	total: 501ms	remaining: 6.18s
# 15:	total: 535ms	remaining: 6.15s
# 16:	total: 569ms	remaining: 6.13s
# 17:	total: 603ms	remaining: 6.09s
# 18:	total: 637ms	remaining: 6.06s
# 19:	total: 681ms	remaining: 6.13s
# 20:	total: 716ms	remaining: 6.1s
# 21:	total: 749ms	remaining: 6.06s
# 22:	total: 781ms	remaining: 6.01s
# 23:	total: 813ms	remaining: 5.96s
# 24:	total: 855ms	remaining: 5.99s
# 25:	total: 894ms	remaining: 5.98s
# 26:	total: 928ms	remaining: 5.94s
# 27:	total: 966ms	remaining: 5.93s
# 28:	total: 1s	remaining: 5.91s
# 29:	total: 1.04s	remaining: 5.93s
# 30:	total: 1.09s	remaining: 5.95s
# 31:	total: 1.13s	remaining: 5.93s
# 32:	total: 1.17s	remaining: 5.91s
# 33:	total: 1.2s	remaining: 5.87s
# 34:	total: 1.24s	remaining: 5.84s
# 35:	total: 1.28s	remaining: 5.84s
# 36:	total: 1.32s	remaining: 5.81s
# 37:	total: 1.35s	remaining: 5.77s
# 38:	total: 1.39s	remaining: 5.73s
# 39:	total: 1.42s	remaining: 5.68s
# 40:	total: 1.46s	remaining: 5.65s
# 41:	total: 1.5s	remaining: 5.64s
# 42:	total: 1.54s	remaining: 5.61s
# 43:	total: 1.57s	remaining: 5.58s
# 44:	total: 1.61s	remaining: 5.54s
# 45:	total: 1.64s	remaining: 5.5s
# 46:	total: 1.69s	remaining: 5.49s
# 47:	total: 1.73s	remaining: 5.47s
# 48:	total: 1.76s	remaining: 5.42s
# 49:	total: 1.8s	remaining: 5.39s
# 50:	total: 1.83s	remaining: 5.35s
# 51:	total: 1.87s	remaining: 5.33s
# 52:	total: 1.92s	remaining: 5.32s
# 53:	total: 1.95s	remaining: 5.28s
# 54:	total: 1.99s	remaining: 5.24s
# 55:	total: 2.02s	remaining: 5.2s
# 56:	total: 2.06s	remaining: 5.16s
# 57:	total: 2.1s	remaining: 5.15s
# 58:	total: 2.14s	remaining: 5.12s
# 59:	total: 2.18s	remaining: 5.1s
# 60:	total: 2.22s	remaining: 5.06s
# 61:	total: 2.26s	remaining: 5.02s
# 62:	total: 2.3s	remaining: 4.99s
# 63:	total: 2.33s	remaining: 4.96s
# 64:	total: 2.37s	remaining: 4.92s
# 65:	total: 2.4s	remaining: 4.88s
# 66:	total: 2.44s	remaining: 4.84s
# 67:	total: 2.48s	remaining: 4.82s
# 68:	total: 2.52s	remaining: 4.78s
# 69:	total: 2.56s	remaining: 4.75s
# 70:	total: 2.59s	remaining: 4.71s
# 71:	total: 2.63s	remaining: 4.67s
# 72:	total: 2.67s	remaining: 4.65s
# 73:	total: 2.71s	remaining: 4.61s
# 74:	total: 2.75s	remaining: 4.58s
# 75:	total: 2.78s	remaining: 4.54s
# 76:	total: 2.82s	remaining: 4.5s
# 77:	total: 2.86s	remaining: 4.47s
# 78:	total: 2.9s	remaining: 4.44s
# 79:	total: 2.93s	remaining: 4.4s
# 80:	total: 2.97s	remaining: 4.36s
# 81:	total: 3s	remaining: 4.32s
# 82:	total: 3.05s	remaining: 4.3s
# 83:	total: 3.09s	remaining: 4.26s
# 84:	total: 3.13s	remaining: 4.23s
# 85:	total: 3.16s	remaining: 4.19s
# 86:	total: 3.2s	remaining: 4.15s
# 87:	total: 3.25s	remaining: 4.13s
# 88:	total: 3.29s	remaining: 4.11s
# 89:	total: 3.33s	remaining: 4.07s
# 90:	total: 3.37s	remaining: 4.03s
# 91:	total: 3.41s	remaining: 4s
# 92:	total: 3.45s	remaining: 3.96s
# 93:	total: 3.48s	remaining: 3.93s
# 94:	total: 3.52s	remaining: 3.89s
# 95:	total: 3.56s	remaining: 3.85s
# 96:	total: 3.59s	remaining: 3.82s
# 97:	total: 3.64s	remaining: 3.79s
# 98:	total: 3.68s	remaining: 3.75s
# 99:	total: 3.72s	remaining: 3.72s
# 100:	total: 3.75s	remaining: 3.68s
# 101:	total: 3.79s	remaining: 3.64s
# 102:	total: 3.83s	remaining: 3.61s
# 103:	total: 3.89s	remaining: 3.59s
# 104:	total: 3.93s	remaining: 3.56s
# 105:	total: 3.97s	remaining: 3.52s
# 106:	total: 4.01s	remaining: 3.49s
# 107:	total: 4.05s	remaining: 3.45s
# 108:	total: 4.09s	remaining: 3.41s
# 109:	total: 4.12s	remaining: 3.37s
# 110:	total: 4.16s	remaining: 3.33s
# 111:	total: 4.19s	remaining: 3.3s
# 112:	total: 4.23s	remaining: 3.26s
# 113:	total: 4.27s	remaining: 3.22s
# 114:	total: 4.3s	remaining: 3.18s
# 115:	total: 4.34s	remaining: 3.14s
# 116:	total: 4.39s	remaining: 3.11s
# 117:	total: 4.42s	remaining: 3.08s
# 118:	total: 4.46s	remaining: 3.04s
# 119:	total: 4.5s	remaining: 3s
# 120:	total: 4.54s	remaining: 2.96s
# 121:	total: 4.58s	remaining: 2.93s
# 122:	total: 4.62s	remaining: 2.89s
# 123:	total: 4.65s	remaining: 2.85s
# 124:	total: 4.69s	remaining: 2.81s
# 125:	total: 4.72s	remaining: 2.77s
# 126:	total: 4.76s	remaining: 2.74s
# 127:	total: 4.8s	remaining: 2.7s
# 128:	total: 4.83s	remaining: 2.66s
# 129:	total: 4.87s	remaining: 2.62s
# 130:	total: 4.9s	remaining: 2.58s
# 131:	total: 4.93s	remaining: 2.54s
# 132:	total: 4.97s	remaining: 2.5s
# 133:	total: 5s	remaining: 2.46s
# 134:	total: 5.04s	remaining: 2.43s
# 135:	total: 5.07s	remaining: 2.39s
# 136:	total: 5.11s	remaining: 2.35s
# 137:	total: 5.15s	remaining: 2.31s
# 138:	total: 5.19s	remaining: 2.28s
# 139:	total: 5.22s	remaining: 2.24s
# 140:	total: 5.25s	remaining: 2.2s
# 141:	total: 5.29s	remaining: 2.16s
# 142:	total: 5.32s	remaining: 2.12s
# 143:	total: 5.37s	remaining: 2.09s
# 144:	total: 5.4s	remaining: 2.05s
# 145:	total: 5.45s	remaining: 2.02s
# 146:	total: 5.49s	remaining: 1.98s
# 147:	total: 5.53s	remaining: 1.94s
# 148:	total: 5.56s	remaining: 1.9s
# 149:	total: 5.6s	remaining: 1.87s
# 150:	total: 5.64s	remaining: 1.83s
# 151:	total: 5.67s	remaining: 1.79s
# 152:	total: 5.71s	remaining: 1.75s
# 153:	total: 5.75s	remaining: 1.72s
# 154:	total: 5.78s	remaining: 1.68s
# 155:	total: 5.83s	remaining: 1.65s
# 156:	total: 5.87s	remaining: 1.61s
# 157:	total: 5.91s	remaining: 1.57s
# 158:	total: 5.95s	remaining: 1.53s
# 159:	total: 5.98s	remaining: 1.5s
# 160:	total: 6.01s	remaining: 1.46s
# 161:	total: 6.05s	remaining: 1.42s
# 162:	total: 6.09s	remaining: 1.38s
# 163:	total: 6.13s	remaining: 1.34s
# 164:	total: 6.17s	remaining: 1.31s
# 165:	total: 6.21s	remaining: 1.27s
# 166:	total: 6.24s	remaining: 1.23s
# 167:	total: 6.28s	remaining: 1.2s
# 168:	total: 6.31s	remaining: 1.16s
# 169:	total: 6.35s	remaining: 1.12s
# 170:	total: 6.39s	remaining: 1.08s
# 171:	total: 6.42s	remaining: 1.04s
# 172:	total: 6.45s	remaining: 1.01s
# 173:	total: 6.49s	remaining: 969ms
# 174:	total: 6.53s	remaining: 933ms
# 175:	total: 6.57s	remaining: 896ms
# 176:	total: 6.61s	remaining: 859ms
# 177:	total: 6.64s	remaining: 821ms
# 178:	total: 6.68s	remaining: 783ms
# 179:	total: 6.71s	remaining: 746ms
# 180:	total: 6.75s	remaining: 709ms
# 181:	total: 6.79s	remaining: 672ms
# 182:	total: 6.82s	remaining: 634ms
# 183:	total: 6.86s	remaining: 596ms
# 184:	total: 6.89s	remaining: 559ms
# 185:	total: 6.93s	remaining: 522ms
# 186:	total: 6.97s	remaining: 485ms
# 187:	total: 7s	remaining: 447ms
# 188:	total: 7.04s	remaining: 410ms
# 189:	total: 7.07s	remaining: 372ms
# 190:	total: 7.12s	remaining: 335ms
# 191:	total: 7.16s	remaining: 298ms
# 192:	total: 7.2s	remaining: 261ms
# 193:	total: 7.23s	remaining: 224ms
# 194:	total: 7.26s	remaining: 186ms
# 195:	total: 7.3s	remaining: 149ms
# 196:	total: 7.33s	remaining: 112ms
# 197:	total: 7.37s	remaining: 74.5ms
# 198:	total: 7.41s	remaining: 37.2ms
# 199:	total: 7.44s	remaining: 0us
# 0:	total: 38.9ms	remaining: 7.75s
# 1:	total: 73.3ms	remaining: 7.25s
# 2:	total: 102ms	remaining: 6.68s
# 3:	total: 131ms	remaining: 6.43s
# 4:	total: 159ms	remaining: 6.22s
# 5:	total: 188ms	remaining: 6.08s
# 6:	total: 215ms	remaining: 5.93s
# 7:	total: 245ms	remaining: 5.87s
# 8:	total: 284ms	remaining: 6.03s
# 9:	total: 316ms	remaining: 6s
# 10:	total: 348ms	remaining: 5.97s
# 11:	total: 380ms	remaining: 5.95s
# 12:	total: 414ms	remaining: 5.95s
# 13:	total: 446ms	remaining: 5.92s
# 14:	total: 485ms	remaining: 5.99s
# 15:	total: 524ms	remaining: 6.02s
# 16:	total: 573ms	remaining: 6.17s
# 17:	total: 607ms	remaining: 6.14s
# 18:	total: 639ms	remaining: 6.09s
# 19:	total: 680ms	remaining: 6.12s
# 20:	total: 716ms	remaining: 6.1s
# 21:	total: 751ms	remaining: 6.08s
# 22:	total: 787ms	remaining: 6.06s
# 23:	total: 822ms	remaining: 6.03s
# 24:	total: 857ms	remaining: 6s
# 25:	total: 893ms	remaining: 5.98s
# 26:	total: 957ms	remaining: 6.13s
# 27:	total: 1s	remaining: 6.16s
# 28:	total: 1.04s	remaining: 6.13s
# 29:	total: 1.07s	remaining: 6.09s
# 30:	total: 1.12s	remaining: 6.12s
# 31:	total: 1.16s	remaining: 6.09s
# 32:	total: 1.2s	remaining: 6.06s
# 33:	total: 1.23s	remaining: 6.01s
# 34:	total: 1.27s	remaining: 5.98s
# 35:	total: 1.3s	remaining: 5.94s
# 36:	total: 1.35s	remaining: 5.94s
# 37:	total: 1.39s	remaining: 5.92s
# 38:	total: 1.43s	remaining: 5.9s
# 39:	total: 1.46s	remaining: 5.86s
# 40:	total: 1.5s	remaining: 5.81s
# 41:	total: 1.54s	remaining: 5.78s
# 42:	total: 1.58s	remaining: 5.77s
# 43:	total: 1.61s	remaining: 5.72s
# 44:	total: 1.65s	remaining: 5.68s
# 45:	total: 1.69s	remaining: 5.65s
# 46:	total: 1.72s	remaining: 5.6s
# 47:	total: 1.77s	remaining: 5.6s
# 48:	total: 1.8s	remaining: 5.56s
# 49:	total: 1.84s	remaining: 5.52s
# 50:	total: 1.88s	remaining: 5.48s
# 51:	total: 1.91s	remaining: 5.45s
# 52:	total: 1.96s	remaining: 5.43s
# 53:	total: 1.99s	remaining: 5.39s
# 54:	total: 2.04s	remaining: 5.39s
# 55:	total: 2.09s	remaining: 5.37s
# 56:	total: 2.12s	remaining: 5.33s
# 57:	total: 2.17s	remaining: 5.3s
# 58:	total: 2.2s	remaining: 5.26s
# 59:	total: 2.24s	remaining: 5.22s
# 60:	total: 2.27s	remaining: 5.18s
# 61:	total: 2.31s	remaining: 5.14s
# 62:	total: 2.35s	remaining: 5.12s
# 63:	total: 2.39s	remaining: 5.08s
# 64:	total: 2.43s	remaining: 5.04s
# 65:	total: 2.46s	remaining: 5s
# 66:	total: 2.5s	remaining: 4.96s
# 67:	total: 2.54s	remaining: 4.92s
# 68:	total: 2.58s	remaining: 4.89s
# 69:	total: 2.61s	remaining: 4.86s
# 70:	total: 2.65s	remaining: 4.82s
# 71:	total: 2.69s	remaining: 4.78s
# 72:	total: 2.72s	remaining: 4.74s
# 73:	total: 2.77s	remaining: 4.72s
# 74:	total: 2.81s	remaining: 4.68s
# 75:	total: 2.84s	remaining: 4.64s
# 76:	total: 2.88s	remaining: 4.59s
# 77:	total: 2.91s	remaining: 4.55s
# 78:	total: 2.95s	remaining: 4.52s
# 79:	total: 2.99s	remaining: 4.48s
# 80:	total: 3.02s	remaining: 4.44s
# 81:	total: 3.06s	remaining: 4.4s
# 82:	total: 3.1s	remaining: 4.36s
# 83:	total: 3.14s	remaining: 4.34s
# 84:	total: 3.18s	remaining: 4.3s
# 85:	total: 3.22s	remaining: 4.27s
# 86:	total: 3.26s	remaining: 4.23s
# 87:	total: 3.29s	remaining: 4.19s
# 88:	total: 3.34s	remaining: 4.16s
# 89:	total: 3.37s	remaining: 4.12s
# 90:	total: 3.4s	remaining: 4.08s
# 91:	total: 3.44s	remaining: 4.04s
# 92:	total: 3.48s	remaining: 4s
# 93:	total: 3.52s	remaining: 3.97s
# 94:	total: 3.56s	remaining: 3.94s
# 95:	total: 3.6s	remaining: 3.89s
# 96:	total: 3.63s	remaining: 3.85s
# 97:	total: 3.66s	remaining: 3.81s
# 98:	total: 3.7s	remaining: 3.78s
# 99:	total: 3.74s	remaining: 3.74s
# 100:	total: 3.77s	remaining: 3.7s
# 101:	total: 3.81s	remaining: 3.66s
# 102:	total: 3.85s	remaining: 3.62s
# 103:	total: 3.89s	remaining: 3.59s
# 104:	total: 3.92s	remaining: 3.55s
# 105:	total: 3.96s	remaining: 3.51s
# 106:	total: 4s	remaining: 3.47s
# 107:	total: 4.04s	remaining: 3.44s
# 108:	total: 4.08s	remaining: 3.41s
# 109:	total: 4.12s	remaining: 3.37s
# 110:	total: 4.16s	remaining: 3.33s
# 111:	total: 4.19s	remaining: 3.29s
# 112:	total: 4.22s	remaining: 3.25s
# 113:	total: 4.26s	remaining: 3.21s
# 114:	total: 4.31s	remaining: 3.18s
# 115:	total: 4.35s	remaining: 3.15s
# 116:	total: 4.39s	remaining: 3.11s
# 117:	total: 4.42s	remaining: 3.07s
# 118:	total: 4.46s	remaining: 3.03s
# 119:	total: 4.49s	remaining: 3s
# 120:	total: 4.53s	remaining: 2.96s
# 121:	total: 4.57s	remaining: 2.92s
# 122:	total: 4.61s	remaining: 2.88s
# 123:	total: 4.64s	remaining: 2.85s
# 124:	total: 4.68s	remaining: 2.81s
# 125:	total: 4.72s	remaining: 2.77s
# 126:	total: 4.76s	remaining: 2.74s
# 127:	total: 4.8s	remaining: 2.7s
# 128:	total: 4.83s	remaining: 2.66s
# 129:	total: 4.87s	remaining: 2.62s
# 130:	total: 4.91s	remaining: 2.58s
# 131:	total: 4.94s	remaining: 2.55s
# 132:	total: 4.98s	remaining: 2.51s
# 133:	total: 5.02s	remaining: 2.47s
# 134:	total: 5.05s	remaining: 2.43s
# 135:	total: 5.1s	remaining: 2.4s
# 136:	total: 5.13s	remaining: 2.36s
# 137:	total: 5.17s	remaining: 2.32s
# 138:	total: 5.2s	remaining: 2.28s
# 139:	total: 5.24s	remaining: 2.24s
# 140:	total: 5.27s	remaining: 2.21s
# 141:	total: 5.31s	remaining: 2.17s
# 142:	total: 5.35s	remaining: 2.13s
# 143:	total: 5.4s	remaining: 2.1s
# 144:	total: 5.44s	remaining: 2.06s
# 145:	total: 5.48s	remaining: 2.03s
# 146:	total: 5.51s	remaining: 1.99s
# 147:	total: 5.55s	remaining: 1.95s
# 148:	total: 5.59s	remaining: 1.91s
# 149:	total: 5.63s	remaining: 1.88s
# 150:	total: 5.67s	remaining: 1.84s
# 151:	total: 5.71s	remaining: 1.8s
# 152:	total: 5.74s	remaining: 1.76s
# 153:	total: 5.78s	remaining: 1.73s
# 154:	total: 5.81s	remaining: 1.69s
# 155:	total: 5.86s	remaining: 1.65s
# 156:	total: 5.89s	remaining: 1.61s
# 157:	total: 5.93s	remaining: 1.58s
# 158:	total: 5.97s	remaining: 1.54s
# 159:	total: 6.01s	remaining: 1.5s
# 160:	total: 6.06s	remaining: 1.47s
# 161:	total: 6.09s	remaining: 1.43s
# 162:	total: 6.13s	remaining: 1.39s
# 163:	total: 6.17s	remaining: 1.35s
# 164:	total: 6.2s	remaining: 1.31s
# 165:	total: 6.25s	remaining: 1.28s
# 166:	total: 6.28s	remaining: 1.24s
# 167:	total: 6.32s	remaining: 1.2s
# 168:	total: 6.35s	remaining: 1.17s
# 169:	total: 6.39s	remaining: 1.13s
# 170:	total: 6.42s	remaining: 1.09s
# 171:	total: 6.47s	remaining: 1.05s
# 172:	total: 6.51s	remaining: 1.02s
# 173:	total: 6.55s	remaining: 979ms
# 174:	total: 6.58s	remaining: 941ms
# 175:	total: 6.62s	remaining: 903ms
# 176:	total: 6.66s	remaining: 865ms
# 177:	total: 6.7s	remaining: 828ms
# 178:	total: 6.73s	remaining: 790ms
# 179:	total: 6.77s	remaining: 752ms
# 180:	total: 6.8s	remaining: 714ms
# 181:	total: 6.83s	remaining: 676ms
# 182:	total: 6.87s	remaining: 638ms
# 183:	total: 6.9s	remaining: 600ms
# 184:	total: 6.93s	remaining: 562ms
# 185:	total: 6.97s	remaining: 524ms
# 186:	total: 7s	remaining: 487ms
# 187:	total: 7.04s	remaining: 449ms
# 188:	total: 7.07s	remaining: 411ms
# 189:	total: 7.11s	remaining: 374ms
# 190:	total: 7.14s	remaining: 337ms
# 191:	total: 7.18s	remaining: 299ms
# 192:	total: 7.21s	remaining: 262ms
# 193:	total: 7.25s	remaining: 224ms
# 194:	total: 7.28s	remaining: 187ms
# 195:	total: 7.31s	remaining: 149ms
# 196:	total: 7.34s	remaining: 112ms
# 197:	total: 7.38s	remaining: 74.6ms
# 198:	total: 7.41s	remaining: 37.3ms
# 199:	total: 7.45s	remaining: 0us
# 0:	total: 31.5ms	remaining: 6.26s
# 1:	total: 61ms	remaining: 6.03s
# 2:	total: 94.4ms	remaining: 6.2s
# 3:	total: 126ms	remaining: 6.2s
# 4:	total: 157ms	remaining: 6.11s
# 5:	total: 190ms	remaining: 6.14s
# 6:	total: 222ms	remaining: 6.11s
# 7:	total: 259ms	remaining: 6.22s
# 8:	total: 306ms	remaining: 6.49s
# 9:	total: 338ms	remaining: 6.43s
# 10:	total: 371ms	remaining: 6.38s
# 11:	total: 406ms	remaining: 6.36s
# 12:	total: 445ms	remaining: 6.4s
# 13:	total: 478ms	remaining: 6.34s
# 14:	total: 509ms	remaining: 6.28s
# 15:	total: 543ms	remaining: 6.25s
# 16:	total: 577ms	remaining: 6.21s
# 17:	total: 613ms	remaining: 6.2s
# 18:	total: 670ms	remaining: 6.38s
# 19:	total: 722ms	remaining: 6.5s
# 20:	total: 760ms	remaining: 6.48s
# 21:	total: 798ms	remaining: 6.46s
# 22:	total: 840ms	remaining: 6.46s
# 23:	total: 876ms	remaining: 6.43s
# 24:	total: 913ms	remaining: 6.39s
# 25:	total: 949ms	remaining: 6.35s
# 26:	total: 991ms	remaining: 6.35s
# 27:	total: 1.03s	remaining: 6.34s
# 28:	total: 1.08s	remaining: 6.35s
# 29:	total: 1.11s	remaining: 6.31s
# 30:	total: 1.15s	remaining: 6.27s
# 31:	total: 1.19s	remaining: 6.24s
# 32:	total: 1.22s	remaining: 6.2s
# 33:	total: 1.27s	remaining: 6.18s
# 34:	total: 1.3s	remaining: 6.15s
# 35:	total: 1.34s	remaining: 6.1s
# 36:	total: 1.38s	remaining: 6.06s
# 37:	total: 1.41s	remaining: 6.02s
# 38:	total: 1.46s	remaining: 6.01s
# 39:	total: 1.49s	remaining: 5.96s
# 40:	total: 1.52s	remaining: 5.91s
# 41:	total: 1.56s	remaining: 5.87s
# 42:	total: 1.6s	remaining: 5.83s
# 43:	total: 1.64s	remaining: 5.83s
# 44:	total: 1.69s	remaining: 5.81s
# 45:	total: 1.73s	remaining: 5.8s
# 46:	total: 1.77s	remaining: 5.78s
# 47:	total: 1.82s	remaining: 5.77s
# 48:	total: 1.86s	remaining: 5.73s
# 49:	total: 1.9s	remaining: 5.69s
# 50:	total: 1.93s	remaining: 5.64s
# 51:	total: 1.96s	remaining: 5.59s
# 52:	total: 2.01s	remaining: 5.58s
# 53:	total: 2.05s	remaining: 5.54s
# 54:	total: 2.09s	remaining: 5.5s
# 55:	total: 2.13s	remaining: 5.47s
# 56:	total: 2.17s	remaining: 5.44s
# 57:	total: 2.21s	remaining: 5.41s
# 58:	total: 2.24s	remaining: 5.36s
# 59:	total: 2.29s	remaining: 5.35s
# 60:	total: 2.33s	remaining: 5.31s
# 61:	total: 2.37s	remaining: 5.28s
# 62:	total: 2.41s	remaining: 5.25s
# 63:	total: 2.45s	remaining: 5.21s
# 64:	total: 2.48s	remaining: 5.16s
# 65:	total: 2.52s	remaining: 5.12s
# 66:	total: 2.56s	remaining: 5.08s
# 67:	total: 2.6s	remaining: 5.05s
# 68:	total: 2.63s	remaining: 5s
# 69:	total: 2.67s	remaining: 4.96s
# 70:	total: 2.7s	remaining: 4.91s
# 71:	total: 2.74s	remaining: 4.87s
# 72:	total: 2.77s	remaining: 4.83s
# 73:	total: 2.81s	remaining: 4.79s
# 74:	total: 2.85s	remaining: 4.75s
# 75:	total: 2.89s	remaining: 4.71s
# 76:	total: 2.92s	remaining: 4.67s
# 77:	total: 2.96s	remaining: 4.63s
# 78:	total: 3s	remaining: 4.6s
# 79:	total: 3.04s	remaining: 4.57s
# 80:	total: 3.08s	remaining: 4.53s
# 81:	total: 3.12s	remaining: 4.49s
# 82:	total: 3.16s	remaining: 4.45s
# 83:	total: 3.21s	remaining: 4.43s
# 84:	total: 3.25s	remaining: 4.4s
# 85:	total: 3.28s	remaining: 4.35s
# 86:	total: 3.32s	remaining: 4.31s
# 87:	total: 3.35s	remaining: 4.27s
# 88:	total: 3.4s	remaining: 4.23s
# 89:	total: 3.43s	remaining: 4.2s
# 90:	total: 3.47s	remaining: 4.16s
# 91:	total: 3.51s	remaining: 4.12s
# 92:	total: 3.54s	remaining: 4.07s
# 93:	total: 3.58s	remaining: 4.03s
# 94:	total: 3.61s	remaining: 3.99s
# 95:	total: 3.64s	remaining: 3.95s
# 96:	total: 3.68s	remaining: 3.91s
# 97:	total: 3.71s	remaining: 3.87s
# 98:	total: 3.75s	remaining: 3.83s
# 99:	total: 3.79s	remaining: 3.79s
# 100:	total: 3.83s	remaining: 3.75s
# 101:	total: 3.87s	remaining: 3.71s
# 102:	total: 3.9s	remaining: 3.68s
# 103:	total: 3.95s	remaining: 3.65s
# 104:	total: 3.98s	remaining: 3.6s
# 105:	total: 4.02s	remaining: 3.56s
# 106:	total: 4.06s	remaining: 3.53s
# 107:	total: 4.1s	remaining: 3.49s
# 108:	total: 4.14s	remaining: 3.46s
# 109:	total: 4.18s	remaining: 3.42s
# 110:	total: 4.21s	remaining: 3.38s
# 111:	total: 4.25s	remaining: 3.34s
# 112:	total: 4.29s	remaining: 3.3s
# 113:	total: 4.34s	remaining: 3.27s
# 114:	total: 4.37s	remaining: 3.23s
# 115:	total: 4.41s	remaining: 3.19s
# 116:	total: 4.44s	remaining: 3.15s
# 117:	total: 4.48s	remaining: 3.11s
# 118:	total: 4.53s	remaining: 3.08s
# 119:	total: 4.56s	remaining: 3.04s
# 120:	total: 4.6s	remaining: 3s
# 121:	total: 4.63s	remaining: 2.96s
# 122:	total: 4.68s	remaining: 2.93s
# 123:	total: 4.72s	remaining: 2.89s
# 124:	total: 4.75s	remaining: 2.85s
# 125:	total: 4.79s	remaining: 2.81s
# 126:	total: 4.83s	remaining: 2.77s
# 127:	total: 4.86s	remaining: 2.74s
# 128:	total: 4.91s	remaining: 2.7s
# 129:	total: 4.94s	remaining: 2.66s
# 130:	total: 4.97s	remaining: 2.62s
# 131:	total: 5.01s	remaining: 2.58s
# 132:	total: 5.04s	remaining: 2.54s
# 133:	total: 5.08s	remaining: 2.5s
# 134:	total: 5.12s	remaining: 2.47s
# 135:	total: 5.16s	remaining: 2.43s
# 136:	total: 5.19s	remaining: 2.39s
# 137:	total: 5.23s	remaining: 2.35s
# 138:	total: 5.26s	remaining: 2.31s
# 139:	total: 5.3s	remaining: 2.27s
# 140:	total: 5.35s	remaining: 2.24s
# 141:	total: 5.39s	remaining: 2.2s
# 142:	total: 5.43s	remaining: 2.16s
# 143:	total: 5.47s	remaining: 2.13s
# 144:	total: 5.5s	remaining: 2.09s
# 145:	total: 5.55s	remaining: 2.05s
# 146:	total: 5.58s	remaining: 2.01s
# 147:	total: 5.62s	remaining: 1.97s
# 148:	total: 5.65s	remaining: 1.93s
# 149:	total: 5.68s	remaining: 1.89s
# 150:	total: 5.72s	remaining: 1.86s
# 151:	total: 5.76s	remaining: 1.82s
# 152:	total: 5.79s	remaining: 1.78s
# 153:	total: 5.83s	remaining: 1.74s
# 154:	total: 5.86s	remaining: 1.7s
# 155:	total: 5.91s	remaining: 1.67s
# 156:	total: 5.95s	remaining: 1.63s
# 157:	total: 5.98s	remaining: 1.59s
# 158:	total: 6.02s	remaining: 1.55s
# 159:	total: 6.05s	remaining: 1.51s
# 160:	total: 6.09s	remaining: 1.48s
# 161:	total: 6.13s	remaining: 1.44s
# 162:	total: 6.17s	remaining: 1.4s
# 163:	total: 6.2s	remaining: 1.36s
# 164:	total: 6.25s	remaining: 1.32s
# 165:	total: 6.28s	remaining: 1.29s
# 166:	total: 6.32s	remaining: 1.25s
# 167:	total: 6.36s	remaining: 1.21s
# 168:	total: 6.4s	remaining: 1.17s
# 169:	total: 6.44s	remaining: 1.14s
# 170:	total: 6.47s	remaining: 1.1s
# 171:	total: 6.51s	remaining: 1.06s
# 172:	total: 6.54s	remaining: 1.02s
# 173:	total: 6.58s	remaining: 983ms
# 174:	total: 6.61s	remaining: 944ms
# 175:	total: 6.65s	remaining: 907ms
# 176:	total: 6.69s	remaining: 869ms
# 177:	total: 6.72s	remaining: 831ms
# 178:	total: 6.76s	remaining: 793ms
# 179:	total: 6.8s	remaining: 755ms
# 180:	total: 6.84s	remaining: 718ms
# 181:	total: 6.88s	remaining: 680ms
# 182:	total: 6.92s	remaining: 643ms
# 183:	total: 6.95s	remaining: 605ms
# 184:	total: 6.99s	remaining: 567ms
# 185:	total: 7.03s	remaining: 529ms
# 186:	total: 7.07s	remaining: 491ms
# 187:	total: 7.1s	remaining: 453ms
# 188:	total: 7.14s	remaining: 416ms
# 189:	total: 7.18s	remaining: 378ms
# 190:	total: 7.21s	remaining: 340ms
# 191:	total: 7.25s	remaining: 302ms
# 192:	total: 7.29s	remaining: 265ms
# 193:	total: 7.33s	remaining: 227ms
# 194:	total: 7.36s	remaining: 189ms
# 195:	total: 7.4s	remaining: 151ms
# 196:	total: 7.43s	remaining: 113ms
# 197:	total: 7.48s	remaining: 75.5ms
# 198:	total: 7.52s	remaining: 37.8ms
# 199:	total: 7.55s	remaining: 0us
# Training completed

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.2344365239734466
# ET-CV: 0.24219880076447614
# RF-CV: 0.24050911085038848
# RF-CV: 0.2740546455949492

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)
# Out:
# (91713, 4),(39308, 4)
# C:\Users\anany\Anaconda3\envs\envTF113\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
test['hospital_death'] = 1 - logistic_regression.predict_proba(x_test)
tackingSubmission = test[["encounter_id","hospital_death"]].to_csv("submission_stacking_5.csv",index=False)
